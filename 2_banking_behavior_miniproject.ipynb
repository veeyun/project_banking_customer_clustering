# %% [markdown]
# ## Banking Behavior

# %%
import pandas as pd

# %%
df_acnts = pd.read_csv("twm_accounts.csv", sep=";")
df_trans = pd.read_csv("twm_transactions.csv", sep=";")

df_check_acnt = pd.read_csv("twm_checking_acct.csv", sep=";")
df_credit_acnt = pd.read_csv("twm_credit_acct.csv", sep=";")
df_saving_acnt = pd.read_csv("twm_savings_acct.csv", sep=";")

df_check_tran = pd.read_csv("twm_checking_tran.csv", sep=";", index_col=False)
df_credit_tran = pd.read_csv("twm_credit_tran.csv", sep=";", index_col=False)
df_saving_tran = pd.read_csv("twm_savings_tran.csv", sep=";", index_col=False)

# %% [markdown]
# ### Data Exploration

# %%
df = df_acnts.groupby(by=["cust_id"]).head()
display(df)
# Out:
#               acct_nbr  cust_id acct_type account_active acct_start_date  \
# 0             13628063  1362806      SV               Y       10.12.1995
# 1     4561143213627090  1362709      CC               Y        15.3.1993
# 2     4561143213628360  1362836      CC               Y        18.3.1992
# 3             13633112  1363311      CK               Y         6.7.1995
# 4     4561143213633610  1363361      CC               Y        17.6.1994
# ...                ...      ...       ...            ...             ...
# 1404  4561143213625560  1362556      CC               N        20.1.1992
# 1405  4561143213626240  1362624      CC               Y       29.11.1990
# 1406  4561143213628750  1362875      CC               Y        24.2.1989
# 1407          13626543  1362654      SV               Y       17.10.1992
# 1408          13627032  1362703      CK               Y        18.9.1994
#
#      acct_end_date  starting_balance  ending_balance
# ...

# %%
print("Accounts")
display(df_acnts.head())

print("All Transactions")
display(df_trans.head())

## Accounts
print("Checking Accounts")
display(df_check_acnt.head())
print("Credit Accounts")
display(df_credit_acnt.head())
print("Savings Accounts")
display(df_credit_acnt.head())

## Transactions
print("Checking Transactions")
display(df_check_tran.head())
print("Credit Transactions")
display(df_credit_tran.head(20))
display(df_credit_tran.tail(20))
print("Savings Transactions")
display(df_saving_tran.head(10))
display(df_saving_tran.tail(10))
# Out:
# Accounts
#            acct_nbr  cust_id acct_type account_active acct_start_date  \
# 0          13628063  1362806      SV               Y       10.12.1995
# 1  4561143213627090  1362709      CC               Y        15.3.1993
# 2  4561143213628360  1362836      CC               Y        18.3.1992
# 3          13633112  1363311      CK               Y         6.7.1995
# 4  4561143213633610  1363361      CC               Y        17.6.1994
#
#   acct_end_date  starting_balance  ending_balance
# 0           NaN           1430.22          284.58
# 1           NaN            266.34          496.15
# 2           NaN             55.90         1000.00
# 3           NaN          11017.13          968.46
# 4           NaN            849.37          462.28
# All Transactions
#    tran_id  acct_nbr  tran_amt  principal_amt  interest_amt  new_balance  \
# 0       27  13625623      0.00           0.00           0.0      3753.34
# ...

# %% [markdown]
# # Information and Descriptions

# %% [markdown]
# # Accounts

# %%
print("Accounts")
df_acnts.info()
display(df_acnts.describe())
# Out:
# Accounts
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1409 entries, 0 to 1408
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acct_nbr          1409 non-null   int64
#  1   cust_id           1409 non-null   int64
#  2   acct_type         1409 non-null   object
#  3   account_active    1409 non-null   object
#  4   acct_start_date   1409 non-null   object
#  5   acct_end_date     143 non-null    object
#  6   starting_balance  1409 non-null   float64
#  7   ending_balance    1409 non-null   float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 88.2+ KB
#            acct_nbr       cust_id  starting_balance  ending_balance
# count  1.409000e+03  1.409000e+03        1409.00000     1409.000000
# mean   1.514986e+15  1.362989e+06        1435.35357     1011.754336
# std    2.148991e+15  2.940584e+02        2186.69662     1559.986310
# ...

# %%
print("Checking Accounts")
df_check_acnt.info()
df_check_acnt.describe()
# Out:
# Checking Accounts
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cust_id           520 non-null    int64
#  1   acct_nbr          520 non-null    int64
#  2   minimum_balance   520 non-null    int64
#  3   per_check_fee     520 non-null    float64
#  4   account_active    520 non-null    object
#  5   acct_start_date   520 non-null    object
#  6   acct_end_date     52 non-null     object
#  7   starting_balance  520 non-null    float64
#  8   ending_balance    520 non-null    float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 36.7+ KB
#             cust_id      acct_nbr  minimum_balance  per_check_fee  \
# count  5.200000e+02  5.200000e+02       520.000000     520.000000
# mean   1.362992e+06  1.362993e+07      1355.384615       0.086250
# std    2.954516e+02  2.954516e+03      1415.769243       0.074223
# ...

# %%
print("Credit Accounts")
df_credit_acnt.info()
df_credit_acnt.describe()
# Out:
# Credit Accounts
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cust_id           468 non-null    int64
#  1   acct_nbr          468 non-null    int64
#  2   credit_limit      468 non-null    int64
#  3   credit_rating     468 non-null    int64
#  4   account_active    468 non-null    object
#  5   acct_start_date   468 non-null    object
#  6   acct_end_date     45 non-null     object
#  7   starting_balance  468 non-null    float64
#  8   ending_balance    468 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 33.0+ KB
#             cust_id      acct_nbr  credit_limit  credit_rating  \
# count  4.680000e+02  4.680000e+02    468.000000     468.000000
# mean   1.362986e+06  4.561143e+15   2647.649573       0.316239
# std    2.920717e+02  2.920717e+03   2293.771202       1.453930
# ...

# %%
print("Saving Accounts")
df_saving_acnt.info()
df_saving_acnt.describe()
# Out:
# Saving Accounts
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cust_id           421 non-null    int64
#  1   acct_nbr          421 non-null    int64
#  2   minimum_balance   421 non-null    int64
#  3   acct_type         421 non-null    object
#  4   account_active    421 non-null    object
#  5   acct_start_date   421 non-null    object
#  6   acct_end_date     46 non-null     object
#  7   starting_balance  421 non-null    float64
#  8   ending_balance    421 non-null    float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 29.7+ KB
#             cust_id      acct_nbr  minimum_balance  starting_balance  \
# count  4.210000e+02  4.210000e+02       421.000000        421.000000
# mean   1.362987e+06  1.362988e+07       194.061758        874.060950
# ...

# %% [markdown]
# # Transactions

# %%
print("Checking Transactions")
df_trans.info()
df_trans.describe()
# Out:
# Checking Transactions
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77580 entries, 0 to 77579
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tran_id        77580 non-null  int64
#  1   acct_nbr       77580 non-null  int64
#  2   tran_amt       77580 non-null  float64
#  3   principal_amt  77580 non-null  float64
#  4   interest_amt   77580 non-null  float64
#  5   new_balance    77580 non-null  float64
#  6   tran_date      77580 non-null  object
#  7   tran_time      77580 non-null  int64
#  8   channel        77580 non-null  object
#  9   tran_code      77580 non-null  object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 5.9+ MB
#             tran_id      acct_nbr      tran_amt  principal_amt  interest_amt  \
# count  77580.000000  7.758000e+04  77580.000000   77580.000000  77580.000000
# mean      38.228332  1.185674e+15     -7.748275      -8.509662      0.762784
# ...

# %%
print("Checking Transactions")
df_credit_tran.info()
df_credit_tran.describe()
# Out:
# Checking Transactions
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20167 entries, 0 to 20166
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cust_id        20167 non-null  int64
#  1   tran_id        20167 non-null  int64
#  2   tran_amt       20167 non-null  float64
#  3   principal_amt  20167 non-null  float64
#  4   interest_amt   20167 non-null  float64
#  5   new_balance    20167 non-null  float64
#  6   tran_date      20167 non-null  object
#  7   tran_time      20167 non-null  object
#  8   channel        20167 non-null  object
#  9   tran_code      20167 non-null  object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 1.5+ MB
#             cust_id       tran_id      tran_amt  principal_amt  interest_amt  \
# count  2.016700e+04  20167.000000  20167.000000   20167.000000  20167.000000
# mean   1.362987e+06     28.543065      0.773537      -1.429786      2.208701
# ...

# %%
print("Checking Transactions")
df_saving_tran.info()
df_saving_tran.describe()
# Out:
# Checking Transactions
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11189 entries, 0 to 11188
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cust_id        11189 non-null  int64
#  1   tran_id        11189 non-null  int64
#  2   tran_amt       11189 non-null  float64
#  3   principal_amt  11189 non-null  float64
#  4   interest_amt   11189 non-null  float64
#  5   new_balance    11189 non-null  float64
#  6   tran_date      11189 non-null  object
#  7   tran_time      11189 non-null  object
#  8   channel        11189 non-null  object
#  9   tran_code      11189 non-null  object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 874.3+ KB
#             cust_id       tran_id      tran_amt  principal_amt  interest_amt  \
# count  1.118900e+04  11189.000000  11189.000000   11189.000000  11189.000000
# mean   1.362988e+06     16.113504     14.458362      13.628621      0.829741
# ...

# %%
df_saving_tran.groupby(by=["cust_id"]).sum()
# Out:
#          tran_id  tran_amt  principal_amt  interest_amt  new_balance
# cust_id
# 1362480      351    482.32         465.30         17.02     30327.79
# 1362484      561   1929.66        1912.47         17.19     32827.05
# 1362486      325   -168.24        -170.34          2.10      3484.15
# 1362487      190   -638.84        -645.47          6.63      6750.71
# 1362489      253   -386.59        -394.68          8.09     10029.50
# ...          ...       ...            ...           ...          ...
# 1363490       78     34.24           0.00         34.24     27429.51
# 1363491      171   -187.63        -188.89          1.26      3733.75
# 1363492      325    164.08         149.67         14.41     25233.52
# 1363493      190    222.43         218.12          4.31     11376.12
# 1363495      666    461.80         420.90         40.90     96650.42
#
# [420 rows x 5 columns]

# %%
print(df_trans["tran_code"].unique())
print(df_check_tran["tran_code"].unique())
print(df_credit_tran["tran_code"].unique())
print(df_saving_tran["tran_code"].unique())
# Out:
# ['IQ  ' 'WD  ' 'FK  ' 'CG  ' 'FP  ' 'CA  ' 'IN  ' 'DP  ' 'PM  ' 'TR  '
#  'FU  ' 'FA  ' 'FM  ']
# ['FK  ' 'WD  ' 'IQ  ' 'TR  ' 'IN  ' 'FU  ' 'FP  ' 'DP  ' 'FM  ']
# ['CG  ' 'IQ  ' 'CA  ' 'PM  ' 'FA  ']
# ['DP  ' 'IN  ' 'WD  ' 'TR  ' 'IQ  ' 'FU  ']

# %%
df_check_tran_summed = df_check_tran.groupby('cust_id', as_index=False).sum()
df_check_tran_summed.head()
# Out:
#    cust_id  tran_id  tran_amt  principal_amt  interest_amt  new_balance
# 0  1362480     4950   -244.99        -244.99          0.00     28876.26
# 1  1362484     4950  -2518.14       -2519.22          1.08     63606.65
# 2  1362485     4950   -164.29        -164.29          0.00     35570.82
# 3  1362486      325   -940.12        -995.22         55.10     91825.71
# 4  1362487     1378  -1378.69       -1409.55         30.86    102757.41

# %%
display(df_credit_tran.shape)
df_credit_tran.duplicated().sum()
# Out:
# (20167, 10)
# 0

# %%
df_saving_tran_grouped = df_saving_tran.groupby('cust_id', as_index=False)

df_saving_tran_summary = pd.DataFrame()
df_saving_tran_summary["cust_id"]  = df_saving_tran_grouped.sum()["cust_id"]
df_saving_tran_summary["SV_tran_tot"]  = df_saving_tran_grouped.sum()["tran_amt"]
df_saving_tran_summary["SV_tran_mean"]  = df_saving_tran_grouped.mean()["tran_amt"]
df_saving_tran_summary["SV_tran_count"]  = df_saving_tran_grouped.count()["tran_amt"]
df_saving_tran_summary = df_saving_tran_summary[["cust_id", "SV_tran_tot", "SV_tran_mean", "SV_tran_count"]]
df_saving_tran_summary.head(10)

# helps us answer how much do people save and are they making lot of small transactions or few huge ones
# Out:
#    cust_id  SV_tran_tot  SV_tran_mean  SV_tran_count
# 0  1362480       482.32     18.550769             26
# 1  1362484      1929.66     58.474545             33
# 2  1362486      -168.24     -6.729600             25
# 3  1362487      -638.84    -33.623158             19
# 4  1362489      -386.59    -17.572273             22
# 5  1362496         3.72      0.310000             12
# 6  1362497      -562.09    -15.191622             37
# 7  1362498        34.34      2.861667             12
# 8  1362500         5.01      0.417500             12
# 9  1362502       469.95     21.361364             22

# %%
df_credit_tran_grouped = df_credit_tran.groupby('cust_id', as_index=False)

df_credit_tran_summary = pd.DataFrame()
df_credit_tran_summary["cust_id"]  = df_credit_tran_grouped.sum()["cust_id"]
df_credit_tran_summary["CC_tran_tot"]  = df_credit_tran_grouped.sum()["tran_amt"]
df_credit_tran_summary["CC_tran_avg"]  = df_credit_tran_grouped.mean()["tran_amt"]
df_credit_tran_summary["CC_tran_count"]  = df_credit_tran_grouped.count()["tran_amt"]
df_credit_tran_summary["CC_int_tot"]  = df_credit_tran_grouped.sum()["interest_amt"]
df_credit_tran_summary = df_credit_tran_summary[["cust_id", "CC_tran_tot", "CC_tran_avg", "CC_tran_count"]]
df_credit_tran_summary.head()

# helps us answer how much do people spend and are they making lot of small transactions or few huge ones
# Out:
#    cust_id  CC_tran_tot  CC_tran_avg  CC_tran_count
# 0  1362480      1948.66    60.895625             32
# 1  1362484       923.87    16.797636             55
# 2  1362485      -761.23   -10.572639             72
# 3  1362487     -1535.59   -47.987187             32
# 4  1362489      1694.18    48.405143             35

# %%
df_savings = df_saving_acnt.merge(df_saving_tran_summary, how='left', on=['cust_id'])

# %%
df_savings.head(10)
# Out:
#    cust_id  acct_nbr  minimum_balance acct_type account_active  \
# 0  1363160  13631603              100      BS               Y
# 1  1362487  13624873              500      MM               N
# 2  1362548  13625483              100      BS               Y
# 3  1362752  13627523              100      BS               Y
# 4  1363017  13630173              100      BS               N
# 5  1362609  13626093              500      MM               Y
# 6  1363465  13634653              500      MM               Y
# 7  1363078  13630783              100      BS               Y
# 8  1362588  13625883              100      BS               Y
# 9  1363343  13633433              500      MM               Y
#
#   acct_start_date acct_end_date  starting_balance  ending_balance  \
# 0        9.5.1988           NaN            113.04          122.54
# 1       27.6.1994     25.8.1995            651.73           12.89
# 2      11.11.1986           NaN            250.24          254.02
# ...

# %%
df_credit = df_credit_acnt.merge(df_credit_tran_summary, how='left', on=['cust_id'])

# %%
df_credit["diff"] = df_credit["starting_balance"] - df_credit["CC_tran_tot"]

# %%
df_credit.head()
# Out:
#    cust_id          acct_nbr  credit_limit  credit_rating account_active  \
# 0  1363160  4561143213631600          1000              0             Y
# 1  1362487  4561143213624870          3000              0             Y
# 2  1362548  4561143213625480          6700              0             Y
# 3  1362752  4561143213627520          2400              0             N
# 4  1363017  4561143213630170          1000              0             Y
#
#   acct_start_date acct_end_date  starting_balance  ending_balance  \
# 0      12.10.1988           NaN            657.46          286.69
# 1        8.8.1995           NaN              0.00         1548.23
# 2      11.11.1986           NaN           6965.25           68.68
# 3       9.10.1994      2.4.1995           2302.14            0.00
# 4        8.2.1995           NaN              0.00         1000.00
#
#    CC_tran_tot  CC_tran_avg  CC_tran_count     diff
# 0       380.03     5.588676           68.0   277.43
# ...

# %%
df_acnts.shape
# Out:
# (1409, 8)

# %%
df_acnts.nunique()
# Out:
# acct_nbr            1409
# cust_id              665
# acct_type              3
# account_active         2
# acct_start_date      951
# acct_end_date        120
# starting_balance    1265
# ending_balance      1213
# dtype: int64

# %%
df_credit_saving = df_credit_tran_summary.merge(df_saving_tran_summary, how="left", on="cust_id")

# %%
df_credit_saving.head()
# Out:
#    cust_id  CC_tran_tot  CC_tran_avg  CC_tran_count  SV_tran_tot  \
# 0  1362480      1948.66    60.895625             32       482.32
# 1  1362484       923.87    16.797636             55      1929.66
# 2  1362485      -761.23   -10.572639             72          NaN
# 3  1362487     -1535.59   -47.987187             32      -638.84
# 4  1362489      1694.18    48.405143             35      -386.59
#
#    SV_tran_mean  SV_tran_count
# 0     18.550769           26.0
# 1     58.474545           33.0
# 2           NaN            NaN
# 3    -33.623158           19.0
# 4    -17.572273           22.0

# %%
df_credit_saving.shape
# Out:
# (457, 7)

# %%
df_saving_acnt["total_savings"] = df_saving_acnt["ending_balance"] - df_saving_acnt["starting_balance"]
df_saving_acnt = df_saving_acnt.rename(columns={"account_active": "SV_active"})
df_saving_acnt.head()
# Out:
#    cust_id  acct_nbr  minimum_balance acct_type SV_active acct_start_date  \
# 0  1363160  13631603              100      BS          Y         9.5.1988
# 1  1362487  13624873              500      MM          N        27.6.1994
# 2  1362548  13625483              100      BS          Y       11.11.1986
# 3  1362752  13627523              100      BS          Y        20.2.1995
# 4  1363017  13630173              100      BS          N        27.4.1994
#
#   acct_end_date  starting_balance  ending_balance  total_savings
# 0           NaN            113.04          122.54           9.50
# 1     25.8.1995            651.73           12.89        -638.84
# 2           NaN            250.24          254.02           3.78
# 3           NaN            600.26          609.33           9.07
# 4    31.10.1995           2011.02         2901.35         890.33

# %%
df_saving_acnt['SV_active'] = df_saving_acnt['SV_active'].str.strip()
df_saving_acnt['SV_active'] = df_saving_acnt['SV_active'].replace('Y', 1)
df_saving_acnt['SV_active'] = df_saving_acnt['SV_active'].replace('N', 0)

# %%
df_saving_acnt
# Out:
#      cust_id  acct_nbr  minimum_balance acct_type  SV_active acct_start_date  \
# 0    1363160  13631603              100      BS            1        9.5.1988
# 1    1362487  13624873              500      MM            0       27.6.1994
# 2    1362548  13625483              100      BS            1      11.11.1986
# 3    1362752  13627523              100      BS            1       20.2.1995
# 4    1363017  13630173              100      BS            0       27.4.1994
# ..       ...       ...              ...       ...        ...             ...
# 416  1363141  13631413              100      BS            1      11.11.1994
# 417  1363038  13630383              100      BS            1       20.2.1995
# 418  1362529  13625293              100      BS            1      15.11.1992
# 419  1362895  13628953              100      BS            1       27.6.1995
# 420  1362855  13628553              100      BS            1       21.3.1995
#
# ...

# %%
df_saving_acnt.shape
# Out:
# (421, 10)

# %%
df_credit_acnt["total_debt"] = df_credit_acnt["ending_balance"] - df_credit_acnt["starting_balance"]
df_credit_acnt = df_credit_acnt.rename(columns={"account_active": "CC_active"})
df_credit_acnt.head()
# Out:
#    cust_id          acct_nbr  credit_limit  credit_rating  CC_active  \
# 0  1363160  4561143213631600          1000              0          1
# 1  1362487  4561143213624870          3000              0          1
# 2  1362548  4561143213625480          6700              0          1
# 3  1362752  4561143213627520          2400              0          0
# 4  1363017  4561143213630170          1000              0          1
#
#   acct_start_date acct_end_date  starting_balance  ending_balance  total_debt
# 0      12.10.1988           NaN            657.46          286.69     -370.77
# 1        8.8.1995           NaN              0.00         1548.23     1548.23
# 2      11.11.1986           NaN           6965.25           68.68    -6896.57
# 3       9.10.1994      2.4.1995           2302.14            0.00    -2302.14
# 4        8.2.1995           NaN              0.00         1000.00     1000.00

# %%
df_credit_acnt.shape
# Out:
# (468, 10)

# %%
df_credit_acnt['account_active'] = df_credit_acnt['account_active'].str.strip()

# %%
df_acnts['account_active'] = df_acnts['account_active'].str.strip()
df_acnts['account_active'] = df_acnts['account_active'].replace('Y', 1)
df_acnts['account_active'] = df_acnts['account_active'].replace('N', 0)

# %%
df_acnts.head()
# Out:
#            acct_nbr  cust_id acct_type  account_active acct_start_date  \
# 0          13628063  1362806      SV                 1      10.12.1995
# 1  4561143213627090  1362709      CC                 1       15.3.1993
# 2  4561143213628360  1362836      CC                 1       18.3.1992
# 3          13633112  1363311      CK                 1        6.7.1995
# 4  4561143213633610  1363361      CC                 1       17.6.1994
#
#   acct_end_date  starting_balance  ending_balance
# 0           NaN           1430.22          284.58
# 1           NaN            266.34          496.15
# 2           NaN             55.90         1000.00
# 3           NaN          11017.13          968.46
# 4           NaN            849.37          462.28

# %%
df_savings_credit.shape
# Out:
# (420, 7)

# %%
df_acnts_merged.shape
# Out:
# (1409, 14)

# %%
df_saving_acnt.shape
# Out:
# (421, 10)

# %%
df_credit_acnt.shape
# Out:
# (468, 10)

# %%
df_check_acnt.shape
# Out:
# (520, 9)

# %%
520 + 468 + 421
# Out:
# 1409

# %%
df_saving_acnt_total_sv = df_saving_acnt[["cust_id", "SV_active", "total_savings"]]
df_credit_acnt_total_debt = df_credit_acnt[["cust_id", "CC_active", "total_debt"]]

# %%
df = df_credit_saving.merge(df_credit_acnt_total_debt, how="left", on="cust_id")

# %%
df = df.merge(df_saving_acnt_total_sv, how="left", on="cust_id")

# %%
df
# Out:
#      cust_id  CC_tran_tot  CC_tran_avg  CC_tran_count  SV_tran_tot  \
# 0    1362480      1948.66    60.895625             32       482.32
# 1    1362484       923.87    16.797636             55      1929.66
# 2    1362485      -761.23   -10.572639             72          NaN
# 3    1362487     -1535.59   -47.987187             32      -638.84
# 4    1362489      1694.18    48.405143             35      -386.59
# ..       ...          ...          ...            ...          ...
# 452  1363483        25.78     0.334805             77          NaN
# 453  1363484       471.14    12.080513             39          NaN
# 454  1363485      3202.51   139.239565             23         2.36
# 455  1363486         0.00     0.000000             38          NaN
# 456  1363492     -1777.14   -61.280690             29       164.08
#
#      SV_tran_mean  SV_tran_count  CC_active  total_debt  SV_active  \
# 0       18.550769           26.0          0    -1587.40        1.0
# ...

# %%
df_customers = pd.read_csv("twm_customer.csv", sep=";")
df_customers.head()
# Out:
#    cust_id  income  age  years_with_bank  nbr_children gender  marital_status  \
# 0  1362691   26150   46                5             1     M                2
# 1  1362487    6605   71                1             0     M                2
# 2  1363160   18548   38                8             0     F                1
# 3  1362752   47668   54                3             0     F                1
# 4  1362548   44554   59                9             2     F                4
#
#   name_prefix                                         first_name  \
# 0              Donald                                        ...
# 1              ChingDyi                                      ...
# 2              Rosa                                          ...
# 3              Lisa                                          ...
# 4              Barbara                                       ...
#
#                                            last_name  street_nbr  \
# ...

# %%
df_customers = df_customers[["cust_id", "income"]]

# %%
df_cust_behav = df.merge(df_customers, how="left", on="cust_id")

# %%
df_cust_behav
# Out:
#      cust_id  CC_tran_tot  CC_tran_avg  CC_tran_count  SV_tran_tot  \
# 0    1362480      1948.66    60.895625             32       482.32
# 1    1362484       923.87    16.797636             55      1929.66
# 2    1362485      -761.23   -10.572639             72          NaN
# 3    1362487     -1535.59   -47.987187             32      -638.84
# 4    1362489      1694.18    48.405143             35      -386.59
# ..       ...          ...          ...            ...          ...
# 452  1363483        25.78     0.334805             77          NaN
# 453  1363484       471.14    12.080513             39          NaN
# 454  1363485      3202.51   139.239565             23         2.36
# 455  1363486         0.00     0.000000             38          NaN
# 456  1363492     -1777.14   -61.280690             29       164.08
#
#      SV_tran_mean  SV_tran_count  CC_active  total_debt  SV_active  \
# 0       18.550769           26.0          0    -1587.40        1.0
# ...

# %%
df_cust_behav = df_cust_behav.fillna(0)

# %%
df_cust_behav.to_csv('cust_banking_behavior.csv', index=False)
